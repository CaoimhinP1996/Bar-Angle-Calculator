# %% [markdown]
# Next steps:
# - github push for to-do list
# - fix best fit line so you can do final mean plot
# - write extinction section
# - write parallax section
# - write double clump section
# - MCMC run for _____ (some priors or range or something to test out)
# - seems like higher latitudes affect fitting quality, also couldn't find many good sightlines as RC is quite sparse, should see how changing which latitudes are included affects fitting results and when it starts to degenerate
#
# Finished:
# 1) Incorporate bar analytic model
# 2) incorporate type/except so it continues when it can't fit or find a sightline file
# 3) Find out what's causing 1sigma to not plot (it was plotting, just not much was there, changed to 3 sigma)
# 4) Make mean parallax vs longitude plot for a latitude
# 5) Test out spread cuts and their effect at farther longitudes (looks inconsistent at wider latitudes, some work and some don't)
# 6) Incorporate parallax sigma cuts
# 7) Figure out how to save to dictionary when not all sightlines have a fit saved to Para (L.append(l) in loop instead of Al in dictionary so that longitude array in dictionary is the same length as the parallax array instead of longer)
# 8) Automate paths for finding files and saving plots in subfolders
# 9) Extend range of longitudes
# 10) Find out why it has Key Error for some files (didn't like sigmaclipping)
# 11) Find out why it can't calculate covariance along some sightlines and which ones (this went away after changing initial guesses)
# 12) Easier to see cuts on CMDs **(9/21)**
# 13) Sigmaclip for parallax separately from redclumpfinder function **(9/21)**
# 14) Incorporated zero-point for parallax **(9/21)**
# 15) Run for b = [-6,0] and turn into one figure with all parallax vs. longitude plots (will need to create a for loop to run each latitude and incorporate parallax vs longitude plot routine into this loop) **(9/21)**
# 16) Produces plots when it can't fit a sightline or has a key error **(9/21)**
# 17) Get functions to import from separate files **(9/21)**
# 18) 2D histogram fit was not working at sightlines closer to the plane of the galaxy as it thinks the RC is the first maximum and not the second because it's artifically cut off; increased magnitude limit when downloading data **(9/21)**
# 19) apply n_init = 10 and algorithm = "elkan" **(10/02)**
# 20) submit abstract **(10/16)**
# 21) Code did NOT like using histogram cuts for fitting; broke the code  **(10/26)**
# 22) zero point distribution and pre-zp distribution of parallax, also plot before and after on mean plot **(10/26)**
# 23) mean parallax is very small all of the sudden both pre and post zero-point correction. test each step (**cause:** was calculating error using parallax) **(10/26)**
# 24) gaussian for parallax **(10/28)**
# 25) drew the zeropoint distribution over the CMD **(10/27)**
# 26) github **(10/27)**
# 27) fixed/changed error for mean parallax measurements **(10/30)**
# 28) downloaded data for 1/6 of a degree **(11/15)**
# 29) fixed issue where Longitude key was a different length than the parallax keys in the final dictionary; placed L.append(l) inside main try and RuntimeError except clauses insead of at the end of the whole block. Not sure why this worked considering Long was always shorter, not longer, than the other keys. **(11/21)**
# 30) turned prezp into a dictionary with specific values from fitcut before turning into a datafram so that it stop giving me a millionn warnings about how I was adding a column **(11/21)**
# 31) mean magnitude and mean color **(11/21)**
# 32) placed all .append() commands after try/except loops and seems to have fixed issue with different lengths **(11/23)**
# 33) got rid of warnings about pseudocolor and nu_eff **(11/21)**
# 34) fit everything for new parallax selection process **(11/23)**
# 35) made a plot of zero-point vs magnitude and zero-point vs. color for diagnostic plots **(11/23)**
# 36) made an altered findRC function and redclumpfinder_v3 and v4 to find it for high extinction areas since the RC will be the first maximum **(11/24)**
# 37) toss out bad fits **(11/24)**
# 38) Best fit line for parallax vs longitude using polynomial **(11/24)**
# 39) plot residuals vs. color and magnitude **(11/24)**
# 40) updated github repository **(11/24)**
# 41) added more diagnostic plots of zero point per star vs zeropoint parameters and parallax **(11/27)**
# 42) altered best fit to quadratic instead of 3rd order polynomial **(11/27)**
# 43) implemented new analytic model **(12/16)**
# 44) implemented Groenwegen zero-point corrections **(12/29)**
# 45) Run for L < -6
# 46) Parallax residuals
# 47) downloaded marshall, SFD, and Gaia TGE dustmaps **(1/4)**
# 48) generated data for model with zero-point free parameter and saved as csvs **(1/12)**
# 49) downloaded positive latitudes
# 50) proper motion included in plots
# 51) make copies of final cuts where you cut anything that seems to have too small of a sample size
# 52) make sure only the Red Clump is dominant
# 53) test for various longitude and latitude ranges to see how it affects measurements
# 54) ran MCMC for positive and negative and fit for bar angle vs latitude
# 55) plot N vs longitude for all latitudes
# 56) plot distance modulus vs longitude for all latitudes
# 57) add difference from gaussian and exponential as a cut to make it less subjective
# 58) put rejections in separate files
# 59) plot gaussian and exponential components of fits in magnitude and color histograms for comparison
# 60) save more columns of data in collective files
# 61) combine latitude files into one file
# 62) sigma is sometimes returned as a negative, but it works if you cut using the absolute value of sigma... not sure why it's negative
# 63) use gaussian sigma from mag fit as the width cut
# 64) store things in data frames using fewer lines
# 65) store all fitting parameters and uncertainties
# 66) see if smaller sightlines decrease differential reddening (l: -2.41, b: -3.03)
# 67) plot mean data all on the same plots
# 68) double clump fitting for magnitude and parallax
# 69) re-implemented zero-point from Groenewegen 2021
# 70) made download code run faster using parallel processing, thank you ChatGPT
# 71) only save sightlines that do not have a obvious double clump and keep double clump sightlines in a separate file to work with later
# 72) made classes of plotting routines depending on what we want to fit for
# 73) make comparison between sightlines CMDs to see if reddening actually becomes less apparent or if we're just making fitting more difficult with less data
# 74) improve guesses and binning (astropy knuth's rule currently), especially for the double parallax which seems to have the biggest issue
# 75) both red clumps should have approximately the same width
# 76) zeropoint fix
# 77) implement differential reddening fix
# 78) check how many stars are in a sightline and toss out ones around 100 or less
# 79) try averaging quarters for each sightline
# 80) check what fraction of stars are tossed out by sigma clipping
# 81) try Groenewegen for different levels
# 82) combine all Gaia data and plot l,b as pixel number as a color to see how resolution changes over area of interest
# 83) mark on mean plot where pixels change for each sightline
# 84) save l value for quarters both in file name and on diagnostic plots
# 85) compute weighted mean, mean, median, and mode
# 86) plot for apparent magnitude vs -5log(p), this will have scatter due to extinction, find best fit and find residuals due to scatter, plot residuals as a function of color (proxy for reddening), plug residuals back into distance modulus and plot modulus vs parallax
# 87) save clip fraction
# 88) print bin values for histograms
# 89) fit for color after fitting for magnitiude
# 90) graphs of differences of mean - mode vs longitude, mean - median vs longitude, and mean - weighted mean vs longitude
# 91) calculate with different HEALPix levels
# 92) check if adding ZP correction from MCMC to new MCMC improves guesses
# 93) run plots and MCMC for median and weighted mean
# 94) plot log of star count instead of avg pixel
# 95) compress Gaia data to upload to box
# 96) notes doc with references to papers you've read and why you're making certain cuts/fitting choices, modules you're using, Gaia team, background
# 97) fix total file
# 98) read about red clump distribution in the bar
# 99) lot dispersion histograms
# 100) histogram of color dispersion and distinctness
# 101) scatter plot of magnitude and color dispersion vs distinctness
